# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os

# Import API key
from api_key import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
cities = pd.read_csv("../output_data/city.csv")

# %%
#My cities into a dataframe
cities_df = pd.DataFrame(cities)
cities_df
# Out:
#      Unnamed: 0               city    lat     lng  max_temp  humidity  \
# 0             0            Ushuaia -54.80  -68.30    277.15        80
# 1             1       Puerto Ayora  -0.74  -90.35    297.15        60
# 2             2         Butaritari   3.07  172.79    301.22        69
# 3             3         Békéscsaba  46.68   21.10    292.04        57
# 4             4            Rikitea -23.12 -134.97    295.46        82
# ..          ...                ...    ...     ...       ...       ...
# 542         542  Guadalupe y Calvo  26.10 -106.97    297.43        38
# 543         543      Ponta Delgada  37.73  -25.67    295.15        83
# 544         544             Gatton -27.55  152.28    285.37        93
# 545         545        Mâncio Lima  -7.61  -72.90    306.15        63
# 546         546        Broken Hill -31.95  141.43    284.15        53
#
#      cloudiness  wind_speed country        date
# 0            40        2.10      AR  1599241310
# 1            20        7.20      EC  1599241311
# 2             7        2.44      KI  1599241312
# 3             0        2.53      HU  1599241177
# 4            48        6.95      PF  1599241315
# ..          ...         ...     ...         ...
# 542          16        5.52      MX  1599242020
# 543          40        6.20      PT  1599242021
# 544          84        0.04      AU  1599242022
# 545          40        2.10      BR  1599242023
# 546           0        1.37      AU  1599242025
#
# [547 rows x 10 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
#Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
#Store 'Lat' and 'Lng' into  locations 
locations = cities_df[["lat", "lng"]].astype(float)

#Converting Humidity to a float for weight on heatmap
humidity = cities_df["humidity"].astype(float)

# %%
#Creating humidity heat map
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=humidity,
                                dissipating=False,
                                max_intensity=100,
                                point_radius=1)
fig.add_layer(heat_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
#My ideal weather 
my_cities = cities_df.loc[(cities_df["max_temp"]<288)&
                          (cities_df["max_temp"]>210)&
                          (cities_df["humidity"]>50)&
                          (cities_df["cloudiness"]<60)&
                          (cities_df["cloudiness"]>30)&
                          (cities_df["wind_speed"]<8)]
my_cities = my_cities.dropna()
my_cities_df = pd.DataFrame(my_cities)
my_cities_df
# Out:
#      Unnamed: 0             city    lat     lng  max_temp  humidity  \
# 0             0          Ushuaia -54.80  -68.30    277.15        80
# 6             6        Esperance -33.87  121.90    284.15        93
# 29           29          Mataura -46.19  168.86    280.37        72
# 40           40          Te Anau -45.42  167.72    278.92        86
# 52           52  Severo-Kuril'sk  50.68  156.12    282.86        82
# 83           83            Tiksi  71.69  128.87    281.50        81
# 118         118     Constitución -35.33  -72.42    286.96        57
# 152         152            Bluff -46.60  168.33    280.37        72
# 236         236          Sørland  67.67   12.69    286.15        93
# 269         269         Flinders -34.58  150.86    287.59        77
# 273         273      Provideniya  64.38 -173.30    277.63        72
# 303         303    Mount Gambier -37.83  140.77    279.15       100
# 354         354            Kiama -34.68  150.87    287.59        66
# 515         515            Semey  50.41   80.23    283.83        51
#
#      cloudiness  wind_speed country        date
# 0            40        2.10      AR  1599241310
# 6            31        4.60      AU  1599241318
# 29           35        4.92      NZ  1599241347
# 40           42        1.78      NZ  1599241361
# 52           34        2.70      RU  1599241377
# 83           57        4.03      RU  1599241417
# 118          50        2.64      CL  1599241463
# 152          36        4.92      NZ  1599241509
# 236          40        3.60      NO  1599241621
# 269          33        0.45      AU  1599241664
# 273          40        1.73      RU  1599241669
# 303          40        3.60      AU  1599241707
# 354          33        4.90      AU  1599241774
# 515          38        5.21      KZ  1599241984

# %%
#Cleaning the my cities df
my_cities_df = my_cities_df[['city',
                            'lat',
                            'lng',
                            'max_temp',
                            'humidity',
                            'cloudiness',
                            'wind_speed',
                            'country']]

my_cities_df = my_cities_df.reset_index(drop=True)
my_cities_df
# Out:
#                city    lat     lng  max_temp  humidity  cloudiness  \
# 0           Ushuaia -54.80  -68.30    277.15        80          40
# 1         Esperance -33.87  121.90    284.15        93          31
# 2           Mataura -46.19  168.86    280.37        72          35
# 3           Te Anau -45.42  167.72    278.92        86          42
# 4   Severo-Kuril'sk  50.68  156.12    282.86        82          34
# 5             Tiksi  71.69  128.87    281.50        81          57
# 6      Constitución -35.33  -72.42    286.96        57          50
# 7             Bluff -46.60  168.33    280.37        72          36
# 8           Sørland  67.67   12.69    286.15        93          40
# 9          Flinders -34.58  150.86    287.59        77          33
# 10      Provideniya  64.38 -173.30    277.63        72          40
# 11    Mount Gambier -37.83  140.77    279.15       100          40
# 12            Kiama -34.68  150.87    287.59        66          33
# 13            Semey  50.41   80.23    283.83        51          38
#
#     wind_speed country
# 0         2.10      AR
# 1         4.60      AU
# 2         4.92      NZ
# 3         1.78      NZ
# 4         2.70      RU
# 5         4.03      RU
# 6         2.64      CL
# 7         4.92      NZ
# 8         3.60      NO
# 9         0.45      AU
# 10        1.73      RU
# 11        3.60      AU
# 12        4.90      AU
# 13        5.21      KZ

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
#Changing variable for hotel map
hotel_df = my_cities_df
hotel_df
# Out:
#                city    lat     lng  max_temp  humidity  cloudiness  \
# 0           Ushuaia -54.80  -68.30    277.15        80          40
# 1         Esperance -33.87  121.90    284.15        93          31
# 2           Mataura -46.19  168.86    280.37        72          35
# 3           Te Anau -45.42  167.72    278.92        86          42
# 4   Severo-Kuril'sk  50.68  156.12    282.86        82          34
# 5             Tiksi  71.69  128.87    281.50        81          57
# 6      Constitución -35.33  -72.42    286.96        57          50
# 7             Bluff -46.60  168.33    280.37        72          36
# 8           Sørland  67.67   12.69    286.15        93          40
# 9          Flinders -34.58  150.86    287.59        77          33
# 10      Provideniya  64.38 -173.30    277.63        72          40
# 11    Mount Gambier -37.83  140.77    279.15       100          40
# 12            Kiama -34.68  150.87    287.59        66          33
# 13            Semey  50.41   80.23    283.83        51          38
#
#     wind_speed country
# 0         2.10      AR
# 1         4.60      AU
# 2         4.92      NZ
# 3         1.78      NZ
# 4         2.70      RU
# 5         4.03      RU
# 6         2.64      CL
# 7         4.92      NZ
# 8         3.60      NO
# 9         0.45      AU
# 10        1.73      RU
# 11        3.60      AU
# 12        4.90      AU
# 13        5.21      KZ

# %%
#Adding hotel column to hotel_df

hotel_df['hotel_name']=""
hotel_df
# Out:
#                city    lat     lng  max_temp  humidity  cloudiness  \
# 0           Ushuaia -54.80  -68.30    277.15        80          40
# 1         Esperance -33.87  121.90    284.15        93          31
# 2           Mataura -46.19  168.86    280.37        72          35
# 3           Te Anau -45.42  167.72    278.92        86          42
# 4   Severo-Kuril'sk  50.68  156.12    282.86        82          34
# 5             Tiksi  71.69  128.87    281.50        81          57
# 6      Constitución -35.33  -72.42    286.96        57          50
# 7             Bluff -46.60  168.33    280.37        72          36
# 8           Sørland  67.67   12.69    286.15        93          40
# 9          Flinders -34.58  150.86    287.59        77          33
# 10      Provideniya  64.38 -173.30    277.63        72          40
# 11    Mount Gambier -37.83  140.77    279.15       100          40
# 12            Kiama -34.68  150.87    287.59        66          33
# 13            Semey  50.41   80.23    283.83        51          38
#
#     wind_speed country hotel_name
# 0         2.10      AR
# 1         4.60      AU
# 2         4.92      NZ
# 3         1.78      NZ
# 4         2.70      RU
# 5         4.03      RU
# 6         2.64      CL
# 7         4.92      NZ
# 8         3.60      NO
# 9         0.45      AU
# 10        1.73      RU
# 11        3.60      AU
# 12        4.90      AU
# 13        5.21      KZ

# %%
#Setting the parameters for the hotels and the loop through hotel_df for coordinates

params = {
    "radius":"5000",
    "types":"lodging",
    "key":g_key,
}

for index, row in hotel_df.iterrows():
    
    #get lat and lng for df
    lat = row['lat']
    lng = row['lng']
    
    #Changing the location with each iteration
    params["location"] = f"{lat},{lng}"
    
    #searching for the hotel by lat and lng
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    
    #make request and print url 
    hotel_names = requests.get(base_url, params=params)
    
    #covert to json
    hotel_names = hotel_names.json()
    
    #adding to the hotel_df
    try:
        hotel_df.loc[index,"hotel_name"] = hotel_names["results"][0]['name']
    except (KeyError, IndexError):
        print("Missing.&.skip")
# Out:
# Missing.&.skip

# %%
hotel_df = pd.DataFrame(hotel_df)
hotel_df
# Out:
#                city    lat     lng  max_temp  humidity  cloudiness  \
# 0           Ushuaia -54.80  -68.30    277.15        80          40
# 1         Esperance -33.87  121.90    284.15        93          31
# 2           Mataura -46.19  168.86    280.37        72          35
# 3           Te Anau -45.42  167.72    278.92        86          42
# 4   Severo-Kuril'sk  50.68  156.12    282.86        82          34
# 5             Tiksi  71.69  128.87    281.50        81          57
# 6      Constitución -35.33  -72.42    286.96        57          50
# 7             Bluff -46.60  168.33    280.37        72          36
# 8           Sørland  67.67   12.69    286.15        93          40
# 9          Flinders -34.58  150.86    287.59        77          33
# 10      Provideniya  64.38 -173.30    277.63        72          40
# 11    Mount Gambier -37.83  140.77    279.15       100          40
# 12            Kiama -34.68  150.87    287.59        66          33
# 13            Semey  50.41   80.23    283.83        51          38
#
#     wind_speed country                                     hotel_name
# 0         2.10      AR                                 Albatros Hotel
# 1         4.60      AU                          Hospitality Esperance
# 2         4.92      NZ                                  Ellie's Villa
# 3         1.78      NZ                        Kingsgate Hotel Te Anau
# 4         2.70      RU                                       Kak Doma
# 5         4.03      RU                                        Arktika
# 6         2.64      CL                    Hotel Boutique Las Azucenas
# 7         4.92      NZ  Bluff Homestead - Guesthouse & Campervan Park
# 8         3.60      NO                            Sjybrygga fiskecamp
# 9         0.45      AU        Shellharbour Resort & Conference Centre
# 10        1.73      RU                                    Provideniya
# 11        3.60      AU                          Commodore on the Park
# 12        4.90      AU                    The Sebel Kiama Harbourside
# 13        5.21      KZ                                Hotel Zhana-Tau

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{hotel_name}</dd>
<dt>City</dt><dd>{city}</dd>
<dt>Country</dt><dd>{country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["lat", "lng"]]

# %%
# Add marker layer ontop of heat map
fig = gmaps.figure()
fig.add_layer(hotel_info)

# Display figure
fig
# Out:
# ---------------------------------------------------------------------------
# TraitError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2251             try:
# -> 2252                 v = self._trait._validate(obj, v)
#    2253             except TraitError:
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    1676         else:
# -> 1677             self.error(obj, value)
#    1678
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in error(self, obj, value)
#    1523
# -> 1524         raise TraitError(e)
#    1525
#
# TraitError: The 'None' trait of a Map instance must be a Widget, but a value of class 'list' (i.e. ['\n<dl>\n<dt>Name</dt><dd>Albatros Hotel</dd>\n<dt>City</dt><dd>Ushuaia</dd>\n<dt>Country</dt><dd>AR</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hospitality Esperance</dd>\n<dt>City</dt><dd>Esperance</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', "\n<dl>\n<dt>Name</dt><dd>Ellie's Villa</dd>\n<dt>City</dt><dd>Mataura</dd>\n<dt>Country</dt><dd>NZ</dd>\n</dl>\n", '\n<dl>\n<dt>Name</dt><dd>Kingsgate Hotel Te Anau</dd>\n<dt>City</dt><dd>Te Anau</dd>\n<dt>Country</dt><dd>NZ</dd>\n</dl>\n', "\n<dl>\n<dt>Name</dt><dd>Kak Doma</dd>\n<dt>City</dt><dd>Severo-Kuril'sk</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n", '\n<dl>\n<dt>Name</dt><dd>Arktika</dd>\n<dt>City</dt><dd>Tiksi</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Boutique Las Azucenas</dd>\n<dt>City</dt><dd>Constitución</dd>\n<dt>Country</dt><dd>CL</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Bluff Homestead - Guesthouse & Campervan Park</dd>\n<dt>City</dt><dd>Bluff</dd>\n<dt>Country</dt><dd>NZ</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Sjybrygga fiskecamp</dd>\n<dt>City</dt><dd>Sørland</dd>\n<dt>Country</dt><dd>NO</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Shellharbour Resort & Conference Centre</dd>\n<dt>City</dt><dd>Flinders</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Provideniya</dd>\n<dt>City</dt><dd>Provideniya</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Commodore on the Park</dd>\n<dt>City</dt><dd>Mount Gambier</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>The Sebel Kiama Harbourside</dd>\n<dt>City</dt><dd>Kiama</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Zhana-Tau</dd>\n<dt>City</dt><dd>Semey</dd>\n<dt>Country</dt><dd>KZ</dd>\n</dl>\n']) was specified.
#
# During handling of the above exception, another exception occurred:
#
# TraitError                                Traceback (most recent call last)
# <ipython-input-32-f29be514f7f1> in <module>
#       1 # Add marker layer ontop of heat map
#       2 fig = gmaps.figure()
# ----> 3 fig.add_layer(hotel_info)
#       4
#       5 # Display figure
#
# ~\anaconda3\lib\site-packages\gmaps\figure.py in add_layer(self, layer)
#     110         except AttributeError:
#     111             pass
# --> 112         self._map.add_layer(layer)
#     113
#     114
#
# ~\anaconda3\lib\site-packages\gmaps\maps.py in add_layer(self, layer)
#     199
#     200     def add_layer(self, layer):
# --> 201         self.layers = tuple([l for l in self.layers] + [layer])
#     202
#     203     @default('layout')
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in __set__(self, obj, value)
#     583             raise TraitError('The "%s" trait is read-only.' % self.name)
#     584         else:
# --> 585             self.set(obj, value)
#     586
#     587     def _validate(self, obj, value):
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in set(self, obj, value)
#     557
#     558     def set(self, obj, value):
# --> 559         new_value = self._validate(obj, value)
#     560         try:
#     561             old_value = obj._trait_values[self.name]
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in _validate(self, obj, value)
#     589             return value
#     590         if hasattr(self, 'validate'):
# --> 591             value = self.validate(obj, value)
#     592         if obj._cross_validation_lock is False:
#     593             value = self._cross_validate(obj, value)
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2322
#    2323     def validate(self, obj, value):
# -> 2324         value = super(List, self).validate(obj, value)
#    2325         value = self.validate_elements(obj, value)
#    2326         return value
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in validate(self, obj, value)
#    2240             return value
#    2241
# -> 2242         value = self.validate_elements(obj, value)
#    2243
#    2244         return value
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2319             self.length_error(obj, value)
#    2320
# -> 2321         return super(List, self).validate_elements(obj, value)
#    2322
#    2323     def validate(self, obj, value):
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in validate_elements(self, obj, value)
#    2252                 v = self._trait._validate(obj, v)
#    2253             except TraitError:
# -> 2254                 self.element_error(obj, v, self._trait)
#    2255             else:
#    2256                 validated.append(v)
#
# ~\anaconda3\lib\site-packages\traitlets\traitlets.py in element_error(self, obj, element, validator)
#    2231         e = "Element of the '%s' trait of %s instance must be %s, but a value of %s was specified." \
#    2232             % (self.name, class_of(obj), validator.info(), repr_type(element))
# -> 2233         raise TraitError(e)
#    2234
#    2235     def validate(self, obj, value):
#
# TraitError: Element of the 'layers' trait of a Map instance must be a Widget, but a value of ['\n<dl>\n<dt>Name</dt><dd>Albatros Hotel</dd>\n<dt>City</dt><dd>Ushuaia</dd>\n<dt>Country</dt><dd>AR</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hospitality Esperance</dd>\n<dt>City</dt><dd>Esperance</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', "\n<dl>\n<dt>Name</dt><dd>Ellie's Villa</dd>\n<dt>City</dt><dd>Mataura</dd>\n<dt>Country</dt><dd>NZ</dd>\n</dl>\n", '\n<dl>\n<dt>Name</dt><dd>Kingsgate Hotel Te Anau</dd>\n<dt>City</dt><dd>Te Anau</dd>\n<dt>Country</dt><dd>NZ</dd>\n</dl>\n', "\n<dl>\n<dt>Name</dt><dd>Kak Doma</dd>\n<dt>City</dt><dd>Severo-Kuril'sk</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n", '\n<dl>\n<dt>Name</dt><dd>Arktika</dd>\n<dt>City</dt><dd>Tiksi</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Boutique Las Azucenas</dd>\n<dt>City</dt><dd>Constitución</dd>\n<dt>Country</dt><dd>CL</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Bluff Homestead - Guesthouse & Campervan Park</dd>\n<dt>City</dt><dd>Bluff</dd>\n<dt>Country</dt><dd>NZ</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Sjybrygga fiskecamp</dd>\n<dt>City</dt><dd>Sørland</dd>\n<dt>Country</dt><dd>NO</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Shellharbour Resort & Conference Centre</dd>\n<dt>City</dt><dd>Flinders</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Provideniya</dd>\n<dt>City</dt><dd>Provideniya</dd>\n<dt>Country</dt><dd>RU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Commodore on the Park</dd>\n<dt>City</dt><dd>Mount Gambier</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>The Sebel Kiama Harbourside</dd>\n<dt>City</dt><dd>Kiama</dd>\n<dt>Country</dt><dd>AU</dd>\n</dl>\n', '\n<dl>\n<dt>Name</dt><dd>Hotel Zhana-Tau</dd>\n<dt>City</dt><dd>Semey</dd>\n<dt>Country</dt><dd>KZ</dd>\n</dl>\n'] <class 'list'> was specified.
